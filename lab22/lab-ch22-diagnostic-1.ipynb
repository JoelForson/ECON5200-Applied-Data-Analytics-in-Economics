# %% [markdown]
# # Lab 22: Clustering Economies — Diagnostic Lab (ECON 5200)
# ## ECON 5200: Causal Machine Learning & Applied Analytics
# ### Diagnosis-First Lab | 40 min Core + 20 min Extension
#
# ---
#
# **Format:** This lab contains **deliberately flawed code and analysis**. Your job:
# 1. Run the code
# 2. Identify what is wrong (not told what to look for)
# 3. Fix the issue
# 4. Document your reasoning
# 5. Extend the corrected analysis
#
# **Topics:** K-Means clustering, feature standardization, PCA visualization, silhouette evaluation, UMAP comparison, reusable Python modules.
#
# **Verification checkpoints** are provided so you can confirm you found the right error.
#
# **Time estimate:** ~60 minutes
#
# ---

# %%
# -----------------------------------------------------------
# GUIDED — Run as-is
# Install required packages and import libraries
# -----------------------------------------------------------
# Use Jupyter magic to install packages within the notebook
# %pip install wbgapi scikit-learn matplotlib seaborn umap-learn -q

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# wbgapi may not be available in all environments immediately.
# The %pip install above runs before the imports in this cell,
# so the import should succeed. If it still fails, restart the kernel
# and re-run this cell.
try:
	import wbgapi as wb
except ModuleNotFoundError:
	print("Module 'wbgapi' not found. If you just installed packages, please restart the kernel and re-run this cell.")
	raise

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, silhouette_samples

np.random.seed(42)

print('Libraries loaded. Ready to diagnose.')
# Out:
#   error: subprocess-exited-with-error
#
#   × Building wheel for numba (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [929 lines of output]
#       TBB not found
#       Using OpenMP from: /opt/anaconda3
#       /private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-q2hz1eb8/overlay/lib/python3.12/site-packages/setuptools/dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: BSD License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba
#       copying numba/_version.py -> build/lib.macosx-10.13-universal2-cpython-312/numba
#       copying numba/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba
#       copying numba/__main__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba
#       copying numba/runtests.py -> build/lib.macosx-10.13-universal2-cpython-312/numba
#       copying numba/extending.py -> build/lib.macosx-10.13-universal2-cpython-312/numba
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/coverage_support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/POST.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/literal.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/gdb_print_extension.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/numba_gdbinfo.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/quicksort.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/numba_entry.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/inspection.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/cffiimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/appdirs.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/init_utils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/firstlinefinder.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/findlib.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/numba_sysinfo.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/gdb_hook.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/llvm_pass_timings.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/mergesort.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/timsort.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/special.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/dump_style.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       copying numba/misc/memoryutils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/experimental
#       copying numba/experimental/function_type.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental
#       copying numba/experimental/structref.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental
#       copying numba/experimental/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/types
#       copying numba/types/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/types
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/fastmathpass.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/dispatcher.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/serialize.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/funcdesc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/postproc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/options.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/transforms.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/compiler_machinery.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/tracing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/event.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/optional.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/ccallback.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/config.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/compiler.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/withcontexts.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/analysis.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/inline_closurecall.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/ir_utils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/registry.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/imputils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/pylowering.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/externals.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/cpu.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/lowering.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/callconv.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/object_mode_passes.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/sigutils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/ssa.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/ir.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/itanium_mangler.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/removerefctpass.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/boxing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/consts.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/intrinsics.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/generators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/descriptors.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/targetconfig.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/interpreter.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/caching.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/utils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/debuginfo.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/cpu_options.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/entrypoints.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/typeinfer.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/llvm_bindings.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/environment.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/errors.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/typed_passes.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/bytecode.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/byteflow.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/untyped_passes.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/callwrapper.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/codegen.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/target_extension.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/controlflow.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/base.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/cgutils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/pythonapi.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/extending.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/compiler_lock.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       copying numba/core/decorators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/cloudpickle
#       copying numba/cloudpickle/cloudpickle.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cloudpickle
#       copying numba/cloudpickle/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cloudpickle
#       copying numba/cloudpickle/cloudpickle_fast.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cloudpickle
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/dispatcher.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/descriptor.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/printimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/libdevice.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/deviceufunc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/cg.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/device_init.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/compiler.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/models.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/intrinsic_wrapper.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/mathimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/initialize.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/vector_types.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/cuda_paths.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/libdevicefuncs.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/simulator_init.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/ufuncs.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/types.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/random.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/intrinsics.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/api.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/stubs.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/vectorizers.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/args.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/target.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/cudamath.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/libdeviceimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/errors.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/cudaimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/nvvmutils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/testing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/cudadecl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/codegen.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/libdevicedecl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/api_util.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/extending.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       copying numba/cuda/decorators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cuda
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/stencils
#       copying numba/stencils/stencil.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/stencils
#       copying numba/stencils/stencilparfor.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/stencils
#       copying numba/stencils/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/stencils
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/pycc
#       copying numba/pycc/cc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/pycc
#       copying numba/pycc/compiler.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/pycc
#       copying numba/pycc/llvm_types.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/pycc
#       copying numba/pycc/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/pycc
#       copying numba/pycc/platform.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/pycc
#       copying numba/pycc/decorators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/pycc
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_map_filter_reduce.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_llvm_version_check.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_builtins.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/chained_assign_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_jitmethod.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_inlining.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_manipulation.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_dictobject.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_linalg.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_function_type.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/parfors_cache_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/typedlist_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_threadsafety.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/cfunc_cache_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/gdb_support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/overload_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/enum_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_debuginfo.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_func_lifetime.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typeinfer.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_unicode.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_asnumbatype.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_return_values.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_parallel_backend.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_nrt.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typeguard.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_vectorization.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_warnings.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typenames.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_moved_modules.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/orphaned_semaphore_usecase.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_mangling.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_npdatetime.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_fancy_indexing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_practical_lowering_issues.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_print.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_parfors_passes.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_ssa.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_debug.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_interproc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_target_extension.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typeconv.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_np_functions.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typedobjectutils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_tracing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_ir_inlining.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_vectorization_type_inference.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/matmul_usecase.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_make_function_to_jit_function.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/complex_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_exprs.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_python_int.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_jitclasses.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_polynomial.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_firstlinefinder.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_obj_lifetime.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_intwidth.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/cloudpickle_main_class.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_llvm_pass_timings.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_pythonapi.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_extending.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_remove_dead.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/serialize_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_funcdesc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_unsafe_intrinsics.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_literal_dispatch.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_listobject.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_unpickle_without_module.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_sys_monitoring.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_gil.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_constants.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/cffi_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_numbers.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_slices.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_mandelbrot.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_numpy_support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/compile_with_pycc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_ir.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_deprecations.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_looplifting.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_storeslice.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/recursion_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/doctest_usecase.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_init_utils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_chrome_trace.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_generators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/dummy_module.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_struct_ref.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_recursion.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_operators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_dictimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_analysis.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_maxmin.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_exceptions.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_comprehension.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/ctypes_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_listimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_locals.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_dicts.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_optional.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_mathlib.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_ir_utils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_numberctor.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_globals.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typingerror.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_object_mode.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_copy_propagate.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_ctypes.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_np_randomgen.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typeof.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_auto_constants.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_cffi.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_try_except.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_sort.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_cfunc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_conversion.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/errorhandling_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_indexing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_pycc.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_byteflow.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/annotation_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_unicode_names.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_findlib.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_extended_arg.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_alignment.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_ndarray_subclasses.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_multi3.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_extending_types.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_import.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_overlap.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_attr.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/error_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_methods.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_conditions_as_predicates.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_func_interface.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_gdb_dwarf.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_event.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_enums.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_profiler.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_numpyadapt.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_mixed_tuple_unroller.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_stencils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_annotations.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/cache_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_sysinfo.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_dataflow.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_doctest.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_tuples.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_svml.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_flow_control.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_iterators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_buffer_protocol.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/inlining_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_casting.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_lists.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_blackscholes.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_analysis.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_config.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_serialize.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_typedlist.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_boundscheck.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_repr.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_heapq.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_iteration.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_fastmath.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_numconv.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/threading_backend_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_runtests.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_errormodels.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_caching.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_recarray_usecases.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_target_overloadselector.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_compile_cache.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_gdb_bindings.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_reductions.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_dyn_func.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_refop_pruning.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_getitem_on_types.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_unpack_sequence.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_cgutils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_api.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_misc_coverage_support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_compiler_lock.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_complex.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_jit_module.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_hashing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_interpreter.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_itanium_mangler.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_parfors_caching.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_sys_stdin_assignment.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_datamodel.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_closure.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_dispatcher.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_ufuncs.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/pdlike_usecase.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_range.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_cli.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_optimisation_pipelines.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_unicode_array.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_compiler_flags.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/parfor_iss9490_usecase.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_num_threads.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_nrt_refct.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_nested_calls.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_chained_assign.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_withlifting.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_errorhandling.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_parfors.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_entrypoints.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_pipeline.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_sets.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_help.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_dyn_array.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_objects.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_record_dtype.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_types.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_codegen.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_random.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_array_return.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       copying numba/tests/test_nan.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/tests
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/testing
#       copying numba/testing/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/testing
#       copying numba/testing/loader.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/testing
#       copying numba/testing/_runtests.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/testing
#       copying numba/testing/notebook.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/testing
#       copying numba/testing/main.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/testing
#       copying numba/testing/__main__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/testing
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/setobj.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/printimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/cmathimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/tupleobj.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/mathimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/unicode.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/heapq.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/builtins.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/randomimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/slicing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/numbers.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/listobj.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/charseq.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/rangeobj.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/unicode_support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/iterators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/enumimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       copying numba/cpython/hashing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cpython
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/parfors
#       copying numba/parfors/parfor_lowering_utils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/parfors
#       copying numba/parfors/parfor_lowering.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/parfors
#       copying numba/parfors/parfor.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/parfors
#       copying numba/parfors/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/parfors
#       copying numba/parfors/array_analysis.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/parfors
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/cext
#       copying numba/cext/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/cext
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/scripts
#       copying numba/scripts/generate_lower_listing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/scripts
#       copying numba/scripts/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/scripts
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       copying numba/typed/typedlist.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       copying numba/typed/dictimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       copying numba/typed/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       copying numba/typed/listobject.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       copying numba/typed/dictobject.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       copying numba/typed/typedobjectutils.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       copying numba/typed/typeddict.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/typed
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/ufunc_db.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/npyimpl.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/numpy_support.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/extensions.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/arraymath.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/linalg.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/npdatetime_helpers.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/npyfuncs.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/arrayobj.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       copying numba/np/npdatetime.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/np
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/misc/help
#       copying numba/misc/help/inspector.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc/help
#       copying numba/misc/help/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/misc/help
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass
#       copying numba/experimental/jitclass/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass
#       copying numba/experimental/jitclass/boxing.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass
#       copying numba/experimental/jitclass/overloads.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass
#       copying numba/experimental/jitclass/base.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass
#       copying numba/experimental/jitclass/decorators.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/core/typeconv
#       copying numba/core/typeconv/typeconv.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/typeconv
#       copying numba/core/typeconv/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/typeconv
#       copying numba/core/typeconv/rules.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/typeconv
#       copying numba/core/typeconv/castgraph.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/typeconv
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/core/rewrites
#       copying numba/core/rewrites/ir_print.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/rewrites
#       copying numba/core/rewrites/registry.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/rewrites
#       copying numba/core/rewrites/static_raise.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/rewrites
#       copying numba/core/rewrites/__init__.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/rewrites
#       copying numba/core/rewrites/static_getitem.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/rewrites
#       copying numba/core/rewrites/static_binop.py -> build/lib.macosx-10.13-universal2-cpython-312/numba/core/rewrites
#       creating build/lib.macosx-10.13-universal2-cpython-312/numba/core/types
# ...
#       building 'numba.mviewbuf' extension
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/mviewbuf.c -o build/temp.macosx-10.13-universal2-cpython-312/numba/mviewbuf.o
#       clang -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -g build/temp.macosx-10.13-universal2-cpython-312/numba/mviewbuf.o -o build/lib.macosx-10.13-universal2-cpython-312/numba/mviewbuf.cpython-312-darwin.so -headerpad_max_install_names
#       building 'numba.core.runtime._nrt_python' extension
#       creating build/temp.macosx-10.13-universal2-cpython-312/numba/core/runtime
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -I/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-q2hz1eb8/normal/lib/python3.12/site-packages/numpy/_core/include -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/core/runtime/_nrt_pythonmod.c -o build/temp.macosx-10.13-universal2-cpython-312/numba/core/runtime/_nrt_pythonmod.o
#       clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -I/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-q2hz1eb8/normal/lib/python3.12/site-packages/numpy/_core/include -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/core/runtime/nrt.cpp -o build/temp.macosx-10.13-universal2-cpython-312/numba/core/runtime/nrt.o
#       clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -g build/temp.macosx-10.13-universal2-cpython-312/numba/core/runtime/_nrt_pythonmod.o build/temp.macosx-10.13-universal2-cpython-312/numba/core/runtime/nrt.o -lm -o build/lib.macosx-10.13-universal2-cpython-312/numba/core/runtime/_nrt_python.cpython-312-darwin.so
#       building 'numba.experimental.jitclass._box' extension
#       creating build/temp.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/experimental/jitclass/_box.c -o build/temp.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass/_box.o
#       clang -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -g build/temp.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass/_box.o -o build/lib.macosx-10.13-universal2-cpython-312/numba/experimental/jitclass/_box.cpython-312-darwin.so
#       building 'numba.cuda.cudadrv._extras' extension
#       creating build/temp.macosx-10.13-universal2-cpython-312/numba/cuda/cudadrv
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -Inumba -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/cuda/cudadrv/_extras.c -o build/temp.macosx-10.13-universal2-cpython-312/numba/cuda/cudadrv/_extras.o
#       clang -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -g build/temp.macosx-10.13-universal2-cpython-312/numba/cuda/cudadrv/_extras.o -o build/lib.macosx-10.13-universal2-cpython-312/numba/cuda/cudadrv/_extras.cpython-312-darwin.so
#       building 'numba._devicearray' extension
#       clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -Inumba -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/_devicearray.cpp -o build/temp.macosx-10.13-universal2-cpython-312/numba/_devicearray.o -std=c++11
#       numba/_devicearray.cpp:20:5: warning: private field 'ob_base' is not used [-Wunused-private-field]
#           PyObject_HEAD
#           ^
#       /Library/Frameworks/Python.framework/Versions/3.12/include/python3.12/object.h:79:50: note: expanded from macro 'PyObject_HEAD'
#       #define PyObject_HEAD                   PyObject ob_base;
#                                                        ^
#       1 warning generated.
#       numba/_devicearray.cpp:20:5: warning: private field 'ob_base' is not used [-Wunused-private-field]
#           PyObject_HEAD
#           ^
#       /Library/Frameworks/Python.framework/Versions/3.12/include/python3.12/object.h:79:50: note: expanded from macro 'PyObject_HEAD'
#       #define PyObject_HEAD                   PyObject ob_base;
#                                                        ^
#       1 warning generated.
#       clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -bundle -undefined dynamic_lookup -arch arm64 -arch x86_64 -g build/temp.macosx-10.13-universal2-cpython-312/numba/_devicearray.o -o build/lib.macosx-10.13-universal2-cpython-312/numba/_devicearray.cpython-312-darwin.so
#       building 'numba.np.ufunc.omppool' extension
#       clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/np/ufunc/gufunc_scheduler.cpp -o build/temp.macosx-10.13-universal2-cpython-312/numba/np/ufunc/gufunc_scheduler.o -Xclang -fopenmp -std=c++11
#       numba/np/ufunc/gufunc_scheduler.cpp:95:28: warning: format specifies type 'ptrdiff_t' (aka 'long') but the argument has type 'std::vector<long long>::value_type' (aka 'long long') [-Wformat]
#                   printf("%td ", start[i]);
#                           ~~~    ^~~~~~~~
#                           %lld
#       numba/np/ufunc/gufunc_scheduler.cpp:98:28: warning: format specifies type 'ptrdiff_t' (aka 'long') but the argument has type 'std::vector<long long>::value_type' (aka 'long long') [-Wformat]
#                   printf("%td ", end[i]);
#                           ~~~    ^~~~~~
#                           %lld
#       2 warnings generated.
#       numba/np/ufunc/gufunc_scheduler.cpp:95:28: warning: format specifies type 'ptrdiff_t' (aka 'long') but the argument has type 'std::vector<long long>::value_type' (aka 'long long') [-Wformat]
#                   printf("%td ", start[i]);
#                           ~~~    ^~~~~~~~
#                           %lld
#       numba/np/ufunc/gufunc_scheduler.cpp:98:28: warning: format specifies type 'ptrdiff_t' (aka 'long') but the argument has type 'std::vector<long long>::value_type' (aka 'long long') [-Wformat]
#                   printf("%td ", end[i]);
#                           ~~~    ^~~~~~
#                           %lld
#       2 warnings generated.
#       clang++ -fno-strict-overflow -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -O3 -Wall -arch arm64 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.12/include/python3.12 -c numba/np/ufunc/omppool.cpp -o build/temp.macosx-10.13-universal2-cpython-312/numba/np/ufunc/omppool.o -Xclang -fopenmp -std=c++11
#       numba/np/ufunc/omppool.cpp:12:10: fatal error: 'omp.h' file not found
#       #include <omp.h>
#                ^~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang++' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for numba
#   error: subprocess-exited-with-error
#
#   × Building wheel for llvmlite (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [70 lines of output]
#       /private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/_vendor/wheel/bdist_wheel.py:4: FutureWarning: The 'wheel' package is no longer the canonical location of the 'bdist_wheel' command, and will be removed in a future release. Please update to setuptools v70.1 or later which contains an integrated version of this command.
#         warn(
#       running bdist_wheel
#       Traceback (most recent call last):
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-install-z8yc2u1y/llvmlite_815da6bd6c9447e3815597b9c51807d7/ffi/build.py", line 86, in check_cmake
#           subprocess.run(("cmake", ), check=True, stdout=subprocess.PIPE,
#         File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 548, in run
#           with Popen(*popenargs, **kwargs) as process:
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 1026, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 1955, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: 'cmake'
#
#       The above exception was the direct cause of the following exception:
#
#       Traceback (most recent call last):
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-install-z8yc2u1y/llvmlite_815da6bd6c9447e3815597b9c51807d7/ffi/build.py", line 209, in <module>
#           main()
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-install-z8yc2u1y/llvmlite_815da6bd6c9447e3815597b9c51807d7/ffi/build.py", line 203, in main
#           main_posix('.dylib')
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-install-z8yc2u1y/llvmlite_815da6bd6c9447e3815597b9c51807d7/ffi/build.py", line 189, in main_posix
#           try_cmake(here_dir, build_dir, generator)
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-install-z8yc2u1y/llvmlite_815da6bd6c9447e3815597b9c51807d7/ffi/build.py", line 107, in try_cmake
#           check_cmake()
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-install-z8yc2u1y/llvmlite_815da6bd6c9447e3815597b9c51807d7/ffi/build.py", line 100, in check_cmake
#           raise FileNotFoundError(msg) from e
#       FileNotFoundError: llvmlite needs CMake tools to build. It appears that the 'cmake' tool is either not installed or not found on the path. Please add CMake tools to the build environment and path, they are available from many package managers.
#       Traceback (most recent call last):
#         File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 389, in <module>
#           main()
#         File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 280, in build_wheel
#           return _build_backend().build_wheel(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 441, in build_wheel
#           return _build(['bdist_wheel', '--dist-info-dir', str(metadata_directory)])
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 429, in _build
#           return self._build_with_temp_dir(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 410, in _build_with_temp_dir
#           self.run_setup()
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#         File "<string>", line 200, in <module>
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 117, in setup
#           return distutils.core.setup(**attrs)  # type: ignore[return-value]
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 186, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/_distutils/core.py", line 202, in run_commands
#           dist.run_commands()
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1000, in run_commands
#           self.run_command(cmd)
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/dist.py", line 1107, in run_command
#           super().run_command(command)
#         File "/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-build-env-w5rac8my/overlay/lib/python3.12/site-packages/setuptools/_distutils/dist.py", line 1019, in run_command
#           cmd_obj.run()
#         File "<string>", line 170, in run
#         File "<string>", line 62, in build_library_files
#         File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/subprocess.py", line 571, in run
#           raise CalledProcessError(retcode, process.args,
#       subprocess.CalledProcessError: Command '['/usr/local/bin/python3', '/private/var/folders/x9/jjh0jsds6j95r24k8t86824r0000gn/T/pip-install-z8yc2u1y/llvmlite_815da6bd6c9447e3815597b9c51807d7/ffi/build.py']' returned non-zero exit status 1.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for llvmlite
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> numba, llvmlite
# Note: you may need to restart the kernel to use updated packages.
# Module 'wbgapi' not found. If you just installed packages, please restart the kernel and re-run this cell.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 20
#      15 # wbgapi may not be available in all environments immediately.
#      16 # The %pip install above runs before the imports in this cell,
#      17 # so the import should succeed. If it still fails, restart the kernel
#      18 # and re-run this cell.
#      19 try:
# ---> 20 	import wbgapi as wb
#      21 except ModuleNotFoundError:
#      22 	print("Module 'wbgapi' not found. If you just installed packages, please restart the kernel and re-run this cell.")
#
# ModuleNotFoundError: No module named 'wbgapi'

# %%
# -----------------------------------------------------------
# GUIDED — Run as-is
# Load WDI data (shared setup for all parts)
# -----------------------------------------------------------

indicators = {
    'NY.GDP.PCAP.PP.CD': 'gdp_per_capita_ppp',
    'SP.DYN.LE00.IN': 'life_expectancy',
    'SP.DYN.IMRT.IN': 'infant_mortality',
    'SE.PRM.ENRR': 'primary_enrollment',
    'SI.POV.GINI': 'gini_index',
    'EN.ATM.CO2E.PC': 'co2_per_capita',
    'IT.NET.USER.ZS': 'internet_users_pct',
    'NE.TRD.GNFS.ZS': 'trade_pct_gdp',
    'SL.UEM.TOTL.ZS': 'unemployment_rate',
    'SP.URB.TOTL.IN.ZS': 'urban_population_pct'
}

feature_names = list(indicators.values())

df = wb.data.DataFrame(list(indicators.keys()), mrv=1, labels=True)
df = df.rename(columns=indicators)
df = df.dropna(thresh=7)
df = df.fillna(df.median())

print(f'Countries retained: {len(df)}')
print(f'Features: {feature_names}')

# %% [markdown]
# ---
#
# ## Part 1: DIAGNOSE — Find 4 Errors in This Clustering Pipeline
#
# The code below attempts to cluster World Bank economies using K-Means.
# There are **four deliberate errors** spread across four code cells:
#
# 1. A **preprocessing omission** error
# 2. An **API parameter** error
# 3. A **method ordering** error
# 4. A **reproducibility** error
#
# **Your task:** Run each cell, identify the error, explain why it matters,
# and fix it in Part 2.

# %%
# -----------------------------------------------------------
# DIAGNOSE: This code has an error. Find and fix it.
# Step 1: Cluster raw (unstandardized) features
# -----------------------------------------------------------

# ERROR 1: Forgot to standardize before K-Means!
# GDP per capita ranges 300-120,000 while Gini ranges 25-65.
# Without StandardScaler, K-Means clusters almost entirely on GDP.

X_raw = df[feature_names].values  # Using RAW features — no scaling!

kmeans_bad = KMeans(n_clusters=4, init='k-means++', n_init='auto', random_state=42)
labels_bad = kmeans_bad.fit_predict(X_raw)

print('=== Clustering on RAW (unstandardized) features ===')
print(f'Cluster sizes: {np.bincount(labels_bad)}')
print()
for k in range(4):
    mask = labels_bad == k
    print(f'Cluster {k}: {mask.sum()} countries | '
          f'GDP/cap ${df.loc[mask, "gdp_per_capita_ppp"].mean():,.0f} | '
          f'Life Exp {df.loc[mask, "life_expectancy"].mean():.1f}')

print()
print('Notice: clusters are separated ONLY by GDP per capita.')
print('The other 9 features contribute almost nothing to the distance.')

# %%
# -----------------------------------------------------------
# DIAGNOSE: This code has an error. Find and fix it.
# Step 2: Wrong argument name for n_clusters
# -----------------------------------------------------------

# ERROR 2: Using k=4 instead of n_clusters=4
# scikit-learn uses n_clusters, not k. This will raise a TypeError.

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[feature_names])

try:
    kmeans_wrong = KMeans(k=4, init='k-means++', random_state=42)
    kmeans_wrong.fit(X_scaled)
except TypeError as e:
    print(f'ERROR: {e}')
    print()
    print('The correct parameter name is n_clusters, not k.')
    print('scikit-learn\'s KMeans uses: KMeans(n_clusters=4)')

# %%
# -----------------------------------------------------------
# DIAGNOSE: This code has an error. Find and fix it.
# Step 3: PCA applied BEFORE standardization
# -----------------------------------------------------------

# ERROR 3: PCA is applied to raw data, then results are standardized.
# This is backwards! PCA should be applied AFTER standardization.
# PCA finds directions of maximum variance — on raw data, the first PC
# will be dominated by the highest-scale feature (GDP per capita).

# Wrong order: PCA first, then scale
pca_wrong = PCA(n_components=2)
X_pca_wrong = pca_wrong.fit_transform(df[feature_names].values)  # Raw data!
X_pca_then_scaled = StandardScaler().fit_transform(X_pca_wrong)  # Scaling after PCA

print('PCA on RAW data:')
print(f'  PC1 explains {pca_wrong.explained_variance_ratio_[0]:.1%} of variance')
print(f'  PC2 explains {pca_wrong.explained_variance_ratio_[1]:.1%} of variance')
print()
print('PC1 loading vector (top 3):')
loadings = pd.Series(pca_wrong.components_[0], index=feature_names)
top_loadings = loadings.abs().nlargest(3)
for feat in top_loadings.index:
    print(f'  {feat}: {loadings[feat]:.4f}')
print()
print('Notice: PC1 is almost entirely GDP per capita.')
print('Standardize FIRST, then apply PCA.')

# %%
# -----------------------------------------------------------
# DIAGNOSE: This code has an error. Find and fix it.
# Step 4: Missing random_state
# -----------------------------------------------------------

# ERROR 4: No random_state set — results change every time you run!
# K-Means uses random initialization. Without random_state, 
# different runs may converge to different local minima.

X_scaled_ok = StandardScaler().fit_transform(df[feature_names])

# Run K-Means 3 times without random_state
results = []
for trial in range(3):
    km = KMeans(n_clusters=4, init='k-means++', n_init=1)  # No random_state!
    labels = km.fit_predict(X_scaled_ok)
    inertia = km.inertia_
    results.append((labels, inertia))
    print(f'Trial {trial+1}: WCSS = {inertia:.2f}, Cluster sizes = {np.bincount(labels)}')

# Check if results are identical
same_01 = np.array_equal(results[0][0], results[1][0])
same_12 = np.array_equal(results[1][0], results[2][0])
print(f'\nTrial 1 == Trial 2: {same_01}')
print(f'Trial 2 == Trial 3: {same_12}')
print()
if not (same_01 and same_12):
    print('Results differ across runs! Set random_state=42 for reproducibility.')
else:
    print('Results happened to match, but this is NOT guaranteed without random_state.')

# %% [markdown]
# ---
#
# ## Part 2: FIX — Correct the Pipeline
#
# Now write the **correct** clustering pipeline from scratch, fixing all four errors:
#
# 1. **Standardize** features with `StandardScaler` BEFORE clustering
# 2. **Use `n_clusters=4`**, not `k=4`
# 3. **Apply PCA AFTER standardization**, not before
# 4. **Set `random_state=42`** for reproducibility
#
# **Verification checkpoints:**
# - Standardized features should have mean ~ 0, std ~ 1
# - PCA on standardized data: PC1 should explain 35-50% of variance (NOT 90%+)
# - Silhouette score for K=4 should be between 0.15 and 0.40
# - Cluster sizes should be roughly balanced (not 1 giant cluster + 3 tiny ones)

# %%
# -----------------------------------------------------------
# YOUR TASK — Write the corrected clustering pipeline
# Fix all four errors from Part 1
# -----------------------------------------------------------

# Step 1: Standardize features
# YOUR CODE HERE


# Step 2: Fit K-Means with correct parameter name and random_state
# YOUR CODE HERE


# Step 3: Apply PCA to STANDARDIZED data
# YOUR CODE HERE


# Step 4: Visualize — PCA scatter plot colored by cluster
# YOUR CODE HERE


# VERIFICATION
# print(f'Standardized means: {X_scaled.mean(axis=0).round(4)}')
# print(f'PC1 variance explained: {pca.explained_variance_ratio_[0]:.1%}')
# print(f'Silhouette score: {silhouette_score(X_scaled, labels):.4f}')
# print(f'Cluster sizes: {np.bincount(labels)}')

# %% [markdown]
# ---
#
# ## Part 3: EXTEND — Customer Segmentation with Synthetic Data
#
# Move beyond country-level data. In this section, you apply clustering to
# a **customer segmentation** problem using synthetic behavioral data.
# This mirrors how fintechs like Nubank (Chapter 22 opening hook) discover
# customer archetypes from transaction patterns.
#
# Then compare **PCA** and **UMAP** for dimensionality reduction.

# %%
# -----------------------------------------------------------
# GUIDED — Run as-is
# Generate synthetic customer data with 4 latent segments
# -----------------------------------------------------------

from sklearn.datasets import make_blobs

np.random.seed(42)

# Create 4 customer segments with 6 behavioral features
n_customers = 2000
segment_centers = [
    [50, 5, 80, 10, 2, 30],    # Budget-conscious: low spend, few txns, high app usage
    [200, 20, 40, 50, 8, 70],   # Power users: high spend, many txns
    [120, 12, 60, 30, 5, 50],   # Moderate users
    [300, 30, 20, 80, 12, 90],  # Premium: very high spend, low app engagement
]

X_cust, y_true = make_blobs(
    n_samples=n_customers,
    centers=segment_centers,
    cluster_std=[15, 25, 20, 20],
    random_state=42
)

cust_features = [
    'avg_monthly_spend', 'txn_frequency', 'app_sessions',
    'credit_utilization', 'products_held', 'digital_engagement'
]

cust_df = pd.DataFrame(X_cust, columns=cust_features)
cust_df['true_segment'] = y_true

print(f'Customers: {len(cust_df)}')
print(f'Features: {cust_features}')
print(f'True segments: {cust_df["true_segment"].value_counts().sort_index().to_dict()}')
print()
print(cust_df[cust_features].describe().round(1))

# %%
# -----------------------------------------------------------
# YOUR TASK — Cluster customers and compare PCA vs UMAP
# -----------------------------------------------------------

import umap

# Step 1: Standardize customer features
cust_scaler = StandardScaler()
X_cust_scaled = cust_scaler.fit_transform(cust_df[cust_features])

# Step 2: Fit K-Means with K=4 (we know the true number here)
km_cust = KMeans(n_clusters=4, init='k-means++', n_init='auto', random_state=42)
cust_df['kmeans_cluster'] = km_cust.fit_predict(X_cust_scaled)

# Step 3: PCA projection
pca_cust = PCA(n_components=2)
X_pca_cust = pca_cust.fit_transform(X_cust_scaled)

# Step 4: UMAP projection
# Fill in: n_neighbors controls local vs global structure
# n_neighbors=15 is a good default; min_dist=0.1 controls cluster tightness
reducer = umap.UMAP(
    n_neighbors=___,     # FILL IN: try 15
    min_dist=___,        # FILL IN: try 0.1
    n_components=2,
    random_state=42
)
X_umap_cust = reducer.fit_transform(X_cust_scaled)

# Step 5: Side-by-side comparison
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Panel 1: PCA with TRUE labels
scatter1 = axes[0].scatter(X_pca_cust[:, 0], X_pca_cust[:, 1],
                           c=cust_df['true_segment'], cmap='Set1',
                           alpha=0.5, s=15)
axes[0].set_title('PCA — True Segments', fontsize=12)
axes[0].set_xlabel('PC1')
axes[0].set_ylabel('PC2')

# Panel 2: PCA with K-MEANS labels
scatter2 = axes[1].scatter(X_pca_cust[:, 0], X_pca_cust[:, 1],
                           c=cust_df['kmeans_cluster'], cmap='Set1',
                           alpha=0.5, s=15)
axes[1].set_title('PCA — K-Means Clusters', fontsize=12)
axes[1].set_xlabel('PC1')

# Panel 3: UMAP with K-MEANS labels
scatter3 = axes[2].scatter(X_umap_cust[:, 0], X_umap_cust[:, 1],
                           c=cust_df['kmeans_cluster'], cmap='Set1',
                           alpha=0.5, s=15)
axes[2].set_title('UMAP — K-Means Clusters', fontsize=12)
axes[2].set_xlabel('UMAP 1')
axes[2].set_ylabel('UMAP 2')

plt.tight_layout()
plt.show()

# Silhouette comparison
sil_kmeans = silhouette_score(X_cust_scaled, cust_df['kmeans_cluster'])
print(f'Silhouette score (K-Means K=4): {sil_kmeans:.4f}')
print()
print('Compare PCA vs UMAP: Which gives better visual separation?')
print('UMAP preserves local structure better than PCA for non-linear data.')

# %% [markdown]
# ---
#
# ## Part 4: Module Output — `clustering_utils.py`
#
# Write a reusable Python module with three functions for clustering pipelines.
# This is a **portfolio artifact** that demonstrates production-grade unsupervised learning.
#
# ### Requirements
#
# ```python
# # clustering_utils.py
#
# def run_kmeans_pipeline(df, features, k, random_state=42):
#     """End-to-end K-Means pipeline: standardize, fit, return labels + metadata."""
#     ...
#
# def evaluate_k_range(X, k_range, random_state=42):
#     """Compute WCSS and silhouette scores for a range of K values."""
#     ...
#
# def plot_pca_clusters(X, labels, feature_names):
#     """PCA 2D scatter with cluster coloring + loadings annotation."""
#     ...
# ```

# %%
# -----------------------------------------------------------
# YOUR TASK — Write clustering_utils.py
# Implement the three functions below
# -----------------------------------------------------------

# %%writefile clustering_utils.py
"""
clustering_utils.py — Reusable Clustering Pipeline Module

Functions for standardized K-Means clustering, K evaluation,
and PCA visualization.

Author: [Your Name]
Course: ECON 5200, Lab 22
"""

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
from typing import List, Tuple, Dict


def run_kmeans_pipeline(
    df: pd.DataFrame,
    features: List[str],
    k: int,
    random_state: int = 42
) -> Dict:
    """End-to-end K-Means pipeline.
    
    1. Extracts features from DataFrame
    2. Standardizes with StandardScaler
    3. Fits K-Means
    4. Returns labels, scaler, model, and silhouette score
    
    Args:
        df: DataFrame with feature columns
        features: List of column names to use
        k: Number of clusters
        random_state: Random seed for reproducibility
    
    Returns:
        dict with keys: 'labels', 'scaler', 'model', 'X_scaled',
                        'silhouette', 'inertia'
    """
    # YOUR IMPLEMENTATION HERE
    pass


def evaluate_k_range(
    X: np.ndarray,
    k_range: range,
    random_state: int = 42
) -> pd.DataFrame:
    """Evaluate clustering quality across a range of K values.
    
    Computes WCSS (inertia) and silhouette score for each K.
    
    Args:
        X: Standardized feature matrix
        k_range: Range of K values to test (e.g., range(2, 11))
        random_state: Random seed
    
    Returns:
        DataFrame with columns: 'k', 'wcss', 'silhouette'
    """
    # YOUR IMPLEMENTATION HERE
    pass


def plot_pca_clusters(
    X: np.ndarray,
    labels: np.ndarray,
    feature_names: List[str]
) -> None:
    """PCA 2D scatter plot with cluster coloring.
    
    Fits PCA(n_components=2), creates scatter plot colored by cluster,
    and annotates with explained variance ratios.
    
    Args:
        X: Standardized feature matrix
        labels: Cluster labels (array of integers)
        feature_names: List of original feature names
    """
    # YOUR IMPLEMENTATION HERE
    pass


# --- Quick self-test ---
if __name__ == '__main__':
    from sklearn.datasets import make_blobs
    X_test, _ = make_blobs(n_samples=200, centers=3, n_features=5, random_state=0)
    df_test = pd.DataFrame(X_test, columns=[f'f{i}' for i in range(5)])
    
    result = run_kmeans_pipeline(df_test, [f'f{i}' for i in range(5)], k=3)
    print(f'Labels shape: {result["labels"].shape}')
    print(f'Silhouette: {result["silhouette"]:.4f}')
    
    eval_df = evaluate_k_range(result['X_scaled'], range(2, 8))
    print(eval_df)
    
    plot_pca_clusters(result['X_scaled'], result['labels'], [f'f{i}' for i in range(5)])
    print('Self-test passed.')

# %% [markdown]
# ---
#
# ## Challenge: Hierarchical Clustering Comparison
#
# K-Means assumes spherical clusters and requires you to specify K upfront.
# **Agglomerative hierarchical clustering** builds a tree (dendrogram) of
# nested clusters and lets you choose K after inspecting the tree.
#
# Compare K-Means and Agglomerative clustering on the WDI data:
# 1. Fit `AgglomerativeClustering(n_clusters=4)` on the standardized WDI data
# 2. Plot the dendrogram using `scipy.cluster.hierarchy`
# 3. Compare cluster assignments with K-Means — do they agree?

# %%
# -----------------------------------------------------------
# CHALLENGE — Hierarchical clustering + dendrogram
# -----------------------------------------------------------

from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# Step 1: Fit agglomerative clustering
# YOUR CODE HERE


# Step 2: Plot dendrogram
# Hint: linkage_matrix = linkage(X_scaled, method='ward')
#        dendrogram(linkage_matrix, truncate_mode='lastp', p=30)
# YOUR CODE HERE


# Step 3: Cross-tabulate K-Means vs Agglomerative labels
# YOUR CODE HERE


# Step 4: Compare silhouette scores
# YOUR CODE HERE

# %% [markdown]
# ---
#
# ## Digital Portfolio: Institutional Signaling
#
# ### Generate Your Professional README
#
# Copy and paste the prompt below into Claude or ChatGPT. **Do NOT ask the AI to write Python code — only documentation.**
#
# ```text
# "I need help writing a project description for my data science lab.
# **Important Rule:** Do NOT generate any Python code for me.
#
# **What I did in this lab:**
# * Diagnosed and fixed a broken K-Means pipeline (missing standardization,
#   wrong parameter name, PCA before scaling, no random_state)
# * Built a corrected pipeline: StandardScaler -> K-Means -> PCA visualization
# * Applied clustering to customer segmentation with synthetic behavioral data
# * Compared PCA vs UMAP for dimensionality reduction
# * Built a reusable clustering_utils.py module with run_kmeans_pipeline(),
#   evaluate_k_range(), and plot_pca_clusters()
# * Key finding: [FILL IN — what K was optimal? How did PCA vs UMAP compare?]
#
# **Please write a README.md entry including:**
# 1. Project Title: Unsupervised Learning — Clustering & Dimensionality Reduction
# 2. Objective: A professional one-sentence summary
# 3. Methodology: Bullet points of technical steps
# 4. Key Findings: Summary of results
# Make this sound like a professional tech economist wrote it."
# ```
#
# ### Push to GitHub
#
# ```bash
# cd econ-lab-22-clustering
# git add notebooks/ src/ figures/ README.md
# git commit -m "Lab 22: Clustering Economies — K-Means, PCA, UMAP & Module"
# git push origin main
# ```
#
# Submit your GitHub repo link on Canvas.
