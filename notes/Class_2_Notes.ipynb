# %% [markdown]
# <a href="https://colab.research.google.com/github/JoelForson/ECON5200-Applied-Data-Analytics-in-Economics/blob/main/Class_2_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cpi_2026 = 325

# %%
cpi_2026
# Out:
# 325

# %%
cpi_1885 = 9.1

# %%
ratio_cpi_1885_2026 = cpi_2026/cpi_1885

# %%
print(ratio_cpi_1885_2026)
# Out:
# 35.714285714285715

# %%
real_price = 0.02 * ratio_cpi_1885_2026
print(real_price)
# Out:
# 0.7142857142857143

# %%
rgdp = [1,2,3,4,5,6]

# %%
rgdp
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
nations = ["A","B","C","D","E","F"]

# %%
dict = {
    "nations":nations,
    "rgdp":rgdp,
    "inflation": [1,2,3,3,2,1],
    "unemp": [1,2,3,4,5,6]
}

# %%
dict
# Out:
# {'nations': ['A', 'B', 'C', 'D', 'E', 'F'],
#  'rgdp': [1, 2, 3, 4, 5, 6],
#  'inflation': [1, 2, 3, 3, 2, 1],
#  'unemp': [1, 2, 3, 4, 5, 6]}

# %%
import pandas as pd

# %%
data = pd.DataFrame(dict)

# %%
data.head()
# Out:
#   nations  rgdp  inflation  unemp
# 0       A     1          1      1
# 1       B     2          2      2
# 2       C     3          3      3
# 3       D     4          3      4
# 4       E     5          2      5
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rgdp'].plot(kind='hist', bins=20, title='rgdp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['inflation'].plot(kind='hist', bins=20, title='inflation')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['unemp'].plot(kind='hist', bins=20, title='unemp')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# For loops

# %%
data["misery_index"] = data['inflation'] + data['unemp']

# %%
for i in rgdp:
  if i > 3:
    print(i)
# Out:
# 4
# 5
# 6

# %%
data
# Out:
#   nations  rgdp  inflation  unemp  2  4  6  7  misery_index
# 0       A     1          1      1  2  4  6  7             2
# 1       B     2          2      2  2  4  6  7             4
# 2       C     3          3      3  2  4  6  7             6
# 3       D     4          3      4  2  4  6  7             7
# 4       E     5          2      5  2  4  6  7             7
# 5       F     6          1      6  2  4  6  7             7

# %% [markdown]
# For loop with range

# %%
range(len(data))
# Out:
# range(0, 6)

# %%
for i in range(len(data)):
  if data.loc[i,"rgdp"] > 3:
    print(data.loc[i,"nations"])
# Out:
# D
# E
# F
